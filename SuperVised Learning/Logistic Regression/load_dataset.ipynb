# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd
import shutil
import os

# %%
# Download latest version
path = kagglehub.dataset_download("uciml/pima-indians-diabetes-database")

#  Save the path to the dataset files for later use




# Your custom save folder
save_folder = "./datasets/diabetes"

# Create folder
os.makedirs(save_folder, exist_ok=True)

# Copy downloaded files
shutil.copytree(path, save_folder, dirs_exist_ok=True)

print("Dataset saved to:", save_folder)
print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\Surayanarayan\.cache\kagglehub\datasets\uciml\pima-indians-diabetes-database\1.archive...
# 100%|██████████| 8.91k/8.91k [00:00<00:00, 4.61MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Surayanarayan\.cache\kagglehub\datasets\uciml\pima-indians-diabetes-database\versions\1
